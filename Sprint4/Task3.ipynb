// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания 2

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Создать базовый класс Student в C#, который будет представлять информацию о
// студентах. На основе этого класса разработать 2-3 производных класса,
// демонстрирующих принципы наследования и полиморфизма. В каждом из классов
// должны быть реализованы новые атрибуты и методы, а также переопределены
// некоторые методы базового класса для демонстрации полиморфизма.
//
// #### Дополнительное задание
// Добавьте к сущестующим классам (базовыму и производным 3-4 атрибута и метода) создайте явную реализации интерфейса и управление зависимостями

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
using System;
using System.Collections.Generic;

// Интерфейс для научной работы
public interface IResearcher
{
    void ConductResearch();
    void PublishPaper();
    void ApplyForGrants();
}

// Интерфейс для навыков преподавания
public interface ITeachingAssistant
{
    void GradeAssignments();
    void ConductLabSessions();
    void PrepareLectures();
}

// Базовый класс Student
public class Student
{
    private string name;
    private int age;
    private int course;

    public string Name
    {
        get => name;
        set => name = value;
    }

    public int Age
    {
        get => age;
        set => age = value;
    }

    public int Course
    {
        get => course;
        set => course = value;
    }

    public string Email { get; set; } // Новый атрибут
    public string PhoneNumber { get; set; } // Новый атрибут
    public List<string> Skills { get; set; } = new List<string>(); // Новый атрибут

    public Student(string name, int age, int course, string email, string phoneNumber)
    {
        Name = name;
        Age = age;
        Course = course;
        Email = email;
        PhoneNumber = phoneNumber;
    }

    public virtual string GetInfo()
    {
        return $"Студент: {Name}, Возраст: {Age}, Курс: {Course}, Email: {Email}, Телефон: {PhoneNumber}";
    }

    public virtual void Study()
    {
        Console.WriteLine($"{Name} учится.");
    }

    public virtual void TakeExam()
    {
        Console.WriteLine($"{Name} сдаёт экзамен.");
    }

    public void Help(Student student)
    {
        Console.WriteLine($"{Name} помогает {student.Name} с учёбой.");
    }

    public void AddSkill(string skill)
    {
        Skills.Add(skill);
        Console.WriteLine($"{Name} освоил новый навык: {skill}");
    }
}

// Производный класс для студентов бакалавриата
public class BachelorStudent : Student
{
    private string specialty;
    private double gpa;

    public string Specialty
    {
        get => specialty;
        set => specialty = value;
    }

    public double GPA
    {
        get => gpa;
        set => gpa = value;
    }

    public string InternshipStatus { get; private set; } // Новый атрибут
    public bool IsGraduated { get; private set; } // Новый атрибут

    public BachelorStudent(string name, int age, int course, string specialty, double gpa, string email, string phoneNumber)
        : base(name, age, course, email, phoneNumber)
    {
        Specialty = specialty;
        GPA = gpa;
    }

    public override string GetInfo()
    {
        return base.GetInfo() + $", Специальность: {Specialty}, Средний балл: {GPA}";
    }

    public override void Study()
    {
        Console.WriteLine($"{Name} учится по специальности {Specialty}.");
    }

    public void ApplyForInternship(string company)
    {
        InternshipStatus = $"Подана заявка на стажировку в {company}";
        Console.WriteLine($"{Name} подал заявку на стажировку в {company}.");
    }

    public void Graduate()
    {
        if (GPA >= 3.0)
        {
            IsGraduated = true;
            Console.WriteLine($"{Name} успешно окончил бакалавриат.");
        }
        else
        {
            Console.WriteLine($"{Name} не может завершить обучение, так как средний балл ниже порога.");
        }
    }
}

// Производный класс для студентов магистратуры, использует множественное наследование через интерфейсы
public class MasterStudent : Student, IResearcher, ITeachingAssistant
{
    private string thesisTitle;
    private string scientificAdvisor;
    public string ResearchArea { get; set; } // Дополнительный атрибут

    public string ThesisTitle
    {
        get => thesisTitle;
        set => thesisTitle = value;
    }

    public string ScientificAdvisor
    {
        get => scientificAdvisor;
        set => scientificAdvisor = value;
    }

    public List<string> Publications { get; private set; } = new List<string>(); // Новый атрибут

    public MasterStudent(string name, int age, int course, string thesisTitle, string scientificAdvisor, string researchArea, string email, string phoneNumber)
        : base(name, age, course, email, phoneNumber)
    {
        ThesisTitle = thesisTitle;
        ScientificAdvisor = scientificAdvisor;
        ResearchArea = researchArea;
    }

    public override string GetInfo()
    {
        return base.GetInfo() + $", Тема диссертации: {ThesisTitle}, Научный руководитель: {ScientificAdvisor}, Область исследований: {ResearchArea}";
    }

    public override void TakeExam()
    {
        Console.WriteLine($"{Name} сдаёт экзамен под руководством {ScientificAdvisor}.");
    }

    // Явная реализация интерфейса IResearcher
    void IResearcher.ConductResearch()
    {
        Console.WriteLine($"{Name} проводит исследование по теме {ThesisTitle} в области {ResearchArea}.");
    }

    void IResearcher.PublishPaper()
    {
        Publications.Add($"Статья по теме {ThesisTitle}");
        Console.WriteLine($"{Name} публикует статью по теме {ThesisTitle}.");
    }

    void IResearcher.ApplyForGrants()
    {
        Console.WriteLine($"{Name} подаёт заявку на грант для исследования в области {ResearchArea}.");
    }

    // Явная реализация интерфейса ITeachingAssistant
    void ITeachingAssistant.GradeAssignments()
    {
        Console.WriteLine($"{Name} проверяет задания студентов.");
    }

    void ITeachingAssistant.ConductLabSessions()
    {
        Console.WriteLine($"{Name} проводит лабораторные занятия.");
    }

    void ITeachingAssistant.PrepareLectures()
    {
        Console.WriteLine($"{Name} готовит лекции по теме {ResearchArea}.");
    }
}

// Класс для управления зависимостями (Dependency Injection)
public class University
{
    private readonly List<Student> students = new List<Student>();
    private readonly IResearcher researcher;
    private readonly ITeachingAssistant teachingAssistant;

    public University(IResearcher researcher, ITeachingAssistant teachingAssistant)
    {
        this.researcher = researcher;
        this.teachingAssistant = teachingAssistant;
    }

    public void AddStudent(Student student)
    {
        students.Add(student);
        Console.WriteLine($"Добавлен студент: {student.Name}");
    }

    public void ShowAllStudents()
    {
        foreach (var student in students)
        {
            Console.WriteLine(student.GetInfo());
        }
    }

    public void ConductUniversityResearch()
    {
        researcher.ConductResearch();
        researcher.PublishPaper();
        researcher.ApplyForGrants();
    }

    public void ConductUniversityLectures()
    {
        teachingAssistant.PrepareLectures();
        teachingAssistant.ConductLabSessions();
        teachingAssistant.GradeAssignments();
    }
}


        // Создание объектов
        MasterStudent master = new MasterStudent("Елена", 24, 2, "ИИ в медицине", "Др. Смит", "Машинное обучение", "elena@mail.com", "123-456-7890");
        BachelorStudent bachelor = new BachelorStudent("Анна", 20, 3, "Программирование", 4.5, "anna@mail.com", "987-654-3210");

        // Явная реализация интерфейсов
        IResearcher researcher = master;
        ITeachingAssistant teachingAssistant = master;

        // Университет с зависимостями
        var university = new University(researcher, teachingAssistant);

        // Добавление студентов
        university.AddStudent(master);
        university.AddStudent(bachelor);

        // Демонстрация возможностей
        Console.WriteLine("\nВсе студенты:");
        university.ShowAllStudents();

        Console.WriteLine("\nНаучная работа:");
        university.ConductUniversityResearch();

        Console.WriteLine("\nПреподавательская деятельность:");
        university.ConductUniversityLectures();
// Out:
// Добавлен студент: Елена
// Добавлен студент: Анна
//
// Все студенты:
// Студент: Елена, Возраст: 24, Курс: 2, Email: elena@mail.com, Телефон: 123-456-7890, Тема диссертации: ИИ в медицине, Научный руководитель: Др. Смит, Область исследований: Машинное обучение
// Студент: Анна, Возраст: 20, Курс: 3, Email: anna@mail.com, Телефон: 987-654-3210, Специальность: Программирование, Средний балл: 4,5
//
// Научная работа:
// Елена проводит исследование по теме ИИ в медицине в области Машинное обучение.
// Елена публикует статью по теме ИИ в медицине.
// Елена подаёт заявку на грант для исследования в области Машинное обучение.
//
// Преподавательская деятельность:
// Елена готовит лекции по теме Машинное обучение.
// Елена проводит лабораторные занятия.
// Елена проверяет задания студентов.
